# %%
import cv2
import pywt
import matplotlib.pyplot as plt

# %%
# Corrected path
i = cv2.imread('lena.png')

# Check if image loaded
if i is None:
    print("Image not found. Please check the path!")
    exit()

# %%
# Convert to grayscale
i_gray = cv2.cvtColor(i, cv2.COLOR_BGR2GRAY)

# Apply 2D Discrete Wavelet Transform
LL, (LH, HL, HH) = pywt.dwt2(i_gray, 'haar')

# %%
# Plot the four sub-bands
plt.figure(figsize=(10, 8))
plt.subplot(2, 2, 1)
plt.imshow(LL, cmap='gray')
plt.title('Approximation')
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(LH, cmap='gray')
plt.title('Horizontal detail')
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(HL, cmap='gray')
plt.title('Vertical detail')
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(HH, cmap='gray')
plt.title('Diagonal detail')
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
# Sum of all components
x = LL + LH + HL + HH

# Plot original and decomposed images
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(i_gray, cmap='gray')
plt.title('Original image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(x, cmap='gray')
plt.title('Decomposed image')
plt.axis('off')

plt.show()
